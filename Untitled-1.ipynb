# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
from pywaffle import Waffle

# %%
# read the data
df = pd.read_csv('data.csv')
df = df.sort_values(by=['Touches'],ascending=False)
df = df.drop(16)
df = df.drop('Touches',axis = 1)
df = df.T
df.columns = df.iloc[0]
df = df.drop('Player')
my_list = df.columns.values.tolist()
df = pd.DataFrame(df,columns=my_list)
df
# Out:
#         Lisandro Martínez Harry Maguire Diogo Dalot Bruno Fernandes Luke Shaw  \
# Def Pen                17             5           4               0         0
# Def 3rd                61            45          25               9        23
# Mid 3rd                29            36          30              27        29
# Att 3rd                 8             5          23              42        24
# Att Pen                 2             1           5               3         2
#
#         Christian Eriksen Fred Jadon Sancho Scott McTominay Marcus Rashford  \
# Def Pen                 0    2            0               0               0
# Def 3rd                14   16            1               9               0
# Mid 3rd                39   26           15              17              11
# Att 3rd                22    7           24              10              21
# Att Pen                 2    0            5               4               6
#
#         David de Gea Cristiano Ronaldo Donny van de Beek Tyrell Malacia  \
# Def Pen           26                 1                 0              0
# Def 3rd           29                 1                 1              3
# Mid 3rd            0                 3                 2              1
# Att 3rd            0                 8                 7              0
# Att Pen            0                 2                 0              0
#
#         Alejandro Garnacho Anthony Elanga
# Def Pen                  0              0
# Def 3rd                  0              0
# Mid 3rd                  0              1
# Att 3rd                  1              0
# Att Pen                  0              0

# %%
for i in range(len(my_list)):
    fig = plt.figure(
        FigureClass=Waffle,
        values = df.iloc[:,i],
        labels = list(df.index),
        rows = 10,
        title = {
            'label':my_list[i]
        },
        figsize=(5,5),
    )
# Out:
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
# <Waffle size 360x360 with 1 Axes>
